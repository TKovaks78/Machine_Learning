# %% [markdown]
# <font size = 6> <center> 00 - Evaluation Metrics </center> </font>

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/800/1*1WPbfzztdv50V22TpA6njw.png">

# %% [markdown]
# <center>⚠️ <font color="red"><b>This notebook is purely theoretical</b>font> </center>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ML-Pipeline-overview" data-toc-modified-id="ML-Pipeline-overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>ML Pipeline overview</a></span><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Getting-Started" data-toc-modified-id="Getting-Started-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Getting Started</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#Model-selection-&amp;-Evaluation" data-toc-modified-id="Model-selection-&amp;-Evaluation-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Model selection &amp; Evaluation</a></span></li><li><span><a href="#Present-your-solution" data-toc-modified-id="Present-your-solution-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Present your solution</a></span></li><li><span><a href="#Final-Notes-on-the-ML-Pipeline" data-toc-modified-id="Final-Notes-on-the-ML-Pipeline-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Final Notes on the ML Pipeline</a></span></li></ul></li><li><span><a href="#Evaluation-Metrics" data-toc-modified-id="Evaluation-Metrics-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Evaluation Metrics</a></span><ul class="toc-item"><li><span><a href="#Classification-Metrics" data-toc-modified-id="Classification-Metrics-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Classification Metrics</a></span><ul class="toc-item"><li><span><a href="#True-Positive,-True-Negative,-False-Negative,-False-Positive-and-confusion-matrix" data-toc-modified-id="True-Positive,-True-Negative,-False-Negative,-False-Positive-and-confusion-matrix-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>True Positive, True Negative, False Negative, False Positive and confusion matrix</a></span></li><li><span><a href="#Classification-Metrics-Summary" data-toc-modified-id="Classification-Metrics-Summary-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Classification Metrics Summary</a></span></li><li><span><a href="#Example-of-scoring-metrics-vs-random-prediction" data-toc-modified-id="Example-of-scoring-metrics-vs-random-prediction-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Example of scoring metrics vs random prediction</a></span></li><li><span><a href="#Precision-Recall-Trade-off-and-ROC-Curve" data-toc-modified-id="Precision-Recall-Trade-off-and-ROC-Curve-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Precision Recall Trade-off and ROC Curve</a></span></li><li><span><a href="#Double-density-plot" data-toc-modified-id="Double-density-plot-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Double density plot</a></span></li></ul></li><li><span><a href="#Regression-Metrics" data-toc-modified-id="Regression-Metrics-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Regression Metrics</a></span></li><li><span><a href="#Clustering" data-toc-modified-id="Clustering-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Clustering</a></span></li></ul></li></ul></div>

# %% [markdown]
# # ML Pipeline overview

# %% [markdown]
# ## Description

# %% [markdown]
# - Look at the big picture
# - Define business goal
# - Define performance metric
# - Add dataset documentation if it is not too heavy

# %% [markdown]
# **Example:**
#
# With the growing environmental concerns, we are trying to find new ways to tackle climate change with technology. By predicting the forest cover type, we can determine what species to plant in a particular area to increase the climate impact of afforestation.
#
# Each observation is a 30m x 30m patch. The requirement is to predict an integer classification for the forest cover type. The seven types are:
# 1 - Spruce/Fir
# 2 - Lodgepole Pine
# 3 - Ponderosa Pine
# 4 - Cottonwood/Willow
# 5 - Aspen
# 6 - Douglas-fir
# 7 - Krummholz
#
# Our goal is to to predict seven different cover types in four different wilderness areas of the Roosevelt National Forest of Northern Colorado with the best accuracy score.

# %% [markdown]
# ## Getting Started

# %% [markdown]
# - Setup
# - Import libraries
# - Import Dataset

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - Overall dataset (shape, describe, report etc.)
# - Univariate
#     - Distribution
#     - Outliers
#     - Missing values
# - Multivariate
#     - Correlation
#     - Interaction

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# - Data Cleaning
#     - Outliers
#     - NaN
#     - Encoding
# - Split dataset
# - Baseline

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# - Brainstorm
# - Feature Extraction
#     - "Normalize" (distribution, scaling)
#     - Optional
#         - Bucketing
#         - Dimensionality reduction
#     - Feature Selection (filter, wrapper and/or embedded)

# %% [markdown]
# ## Model selection & Evaluation

# %% [markdown]
# - Select best model
# - Hyperparameters tunning
# - Evaluate

# %% [markdown]
# ## Present your solution

# %% [markdown]
# *Not covered here*

# %% [markdown]
# ## Final Notes on the ML Pipeline

# %% [markdown]
# ⚠️ Do not see the pipeline as a step by step process but rather a cyclical process. </br>
# ⚠️ Sometimes it makes more sense to merge or mix certain part (e.g deal directly with NaN during EDA)
# </br></br>
# <u>Example:</u></br>
# - Cycle 1:
#     - Define your business goal and your performance metrics
#     - Quick EDA (shape, head, NaN, distribution)
#     - Quick preprocessing (NaN, OHE, define variables category)
#     - Quick modeling: baseline
# - Cycle 2:
#     - Extended EDA (multivariate)
#     - Feature Engineering (variable construction, selection, testing combination)
#     - Model, tune and evaluate
# - Cycle 3:
#     - EDA to better understand model performance
#     - Feature engineering in response of gathered insights
#     - Model, hyperparameters and evaluate (maybe time to run more advanced model such as XGBoost)

# %% [markdown]
# # Evaluation Metrics

# %% [markdown]
# Defining performance metrics comes first in the ML Pipeline </br>
# Below a quick recap on the different performance metrics

# %% [markdown]
# ## Classification Metrics

# %% [markdown]
# ### True Positive, True Negative, False Negative, False Positive and confusion matrix

# %% [markdown]
# ![image.png](attachment:image.png)
# <center><font size=1>Source: https://developers.google.com/machine-learning/crash-course/classification/true-false-positive-negative </font></center>

# %% [markdown]
# *Example of multiclass confusion matrix*

# %%
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay

# import some data to play with
iris = datasets.load_iris()
X = iris.data
y = iris.target
class_names = iris.target_names

# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
classifier = svm.SVC(kernel="linear", C=0.01).fit(X_train, y_train)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        classifier,
        X_test,
        y_test,
        display_labels=class_names,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Confusion matrix, without normalization
# [[13  0  0]
#  [ 0 10  6]
#  [ 0  0  9]]
# Normalized confusion matrix
# [[1.   0.   0.  ]
#  [0.   0.62 0.38]
#  [0.   0.   1.  ]]

# %% [markdown]
# **How to interpret this?** </br>
# - The diagonal in the middle are the values accurately predicted
# - The 6 on the middle right means that 6 versicolor were predicted as virginica

# %% [markdown]
# ### Classification Metrics Summary

# %% [markdown]
# <img src="https://pbs.twimg.com/media/DabN2p_WsAAjz94?format=jpg&name=large">

# %% [markdown]
# To get a better intuitive understanding on F-score: https://www.quora.com/What-is-an-intuitive-explanation-of-F-score

# %% [markdown]
# <table>
# <thead>
#   <tr>
#     <th style = width:10%>Measure</th>
#     <th >Formula</th>
#     <th >Range</th>
#     <th >Example</th>
#     <th >Intuition</th>
#     <th >When to use?</th>
#     <th >Example</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td >Accuracy</td>
#     <td style = width:10%>$\frac{TP+TN}{TP+TN+FP+FN}$</td>
#     <td>0 to 1</td>
#     <td>0.92</td>
#     <td>Model predict correct class in 92% of cases</td>
#     <td>General measure when you have balanced dataset</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Precision</td>
#     <td>$\frac{TP}{TP+FP}$</td>
#     <td>0 to 1</td>
#     <td>0.92</td>
#     <td>In 8% of the cases, I am <span style="font-weight:bold">including false prediction of the positive class</span></td>
#     <td>You want to be more confident about true positives</td>
#     <td>You'd rather have some spams in your email rather than some regular email in your spams</td>
#   </tr>
#   <tr>
#     <td>Recall/Sensitivity</td>
#     <td>$\frac{TP}{TP+FN}$</td>
#     <td>0 to 1</td>
#     <td>0.92</td>
#     <td>I'm <span style="font-weight:bold">missing </span>8% of the <span style="font-weight:bold">positive cases</span> when predicting </td>
#     <td>You don't want to leave out false negatives</td>
#     <td>You'd rather get some healthy people labeled diabetic over leaving a diabetic person labeled healthy</td>
#   </tr>
#   <tr>
#     <td>Specificity</td>
#     <td>$\frac{TN}{FP+TN}$</td>
#     <td>0 to 1</td>
#     <td>0.92</td>
#     <td>I am <span style="font-weight:bold">missing </span>8% of the <span style="font-weight:bold">negative cases</span> when predicting</td>
#     <td>You want to cover all true negatives</td>
#     <td>You're running a drug test in which all people who test positive go to jail, you don't want false positive her</td>
#   </tr>
#   <tr>
#     <td>F1-score</td>
#     <td>$\frac{2*Precision*Recall}{Precision+Recall}$</td>
#     <td>0 to 1</td>
#     <td>0.92</td>
#     <td>Synthetize Precision and Recall in a single value<br></td>
#     <td>focus more on false positive and false negative</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td colspan="7">Is your model guessing at random?</td>
#   </tr>
#   <tr>
#     <td >MCC</td>
#     <td >$\frac{TP*TN-FP*FN}{\sqrt{(TP+FP)(FN+TN)(FP+TN)(TP+FN)}}$</td>
#     <td>-1 to 1</td>
#     <td>-1</td>
#     <td>binary classifier is completely wrong</td>
#     <td>Binary unbalanced class</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Cohen's Kappa</td>
#     <td>$\frac{P(_0)-P(_e)}{1-P(_e)}$</td>
#     <td>0 to 1</td>
#     <td>1</td>
#     <td>My classifier is not guessing at random</td>
#     <td>Unbalanced class</td>
#     <td></td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ### Example of scoring metrics vs random prediction

# %% [markdown]
# <u>Example:</u> Imagine that you need to predict whether your patient has breast cancer and your dataset looks like that:

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df['target'] = pd.Series(data.target)
df_example = df.iloc[10:20,:]
df_example['target']
# Out:
# 10    0
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 17    0
# 18    0
# 19    1
# Name: target, dtype: int32

# %% [markdown]
# You have only 1/10 patient with breast cancer in your dataset. Now imagine that your model always predict that the patient does not have breast cancer:
# - TP = 9
# - TN = 0
# - FP = 1
# - FN = 0
#
#
# Now if we calculate the score for each different metric:
# - $Accuracy = \frac{TP+TN}{TP+TN+FP+FN} = \frac{9+0}{9+0+1+0} = 90\% $
# - $Precision = \frac{TP}{TP+FP}=\frac{9}{9+1}=90\%$
# - $Recall = \frac{TP}{TP+FN} = \frac{9}{9+0}=100\%$
# - $F1-score = \frac{2*Precision*Recall}{Precision+Recall} = \frac{2*TP}{2*TP+FP+FN}= \frac{2*9}{2*9+1+0} = \frac{18}{19} = 94\% $
# - $Specificity = \frac{TN}{FP+TN}=\frac{0}{1+0}=0\%$
# - $MCC = \frac{TP*TN-FP*FN}{\sqrt{(TP+FP)(FN+TN)(FP+TN)(TP+FN)}}= \frac{9*0-1*0}{\sqrt{(TP+FP)(FN+TN)(FP+TN)(TP+FN)}} = 0$
# - **Cohen' Kappa**
#     - Total = TP+TN+FP+FN
#     - $p_0 = \frac{TP+TN}{Total} = \frac{9+0}{10} = 0.9$
#     - $p_e = p_{yes} + p_{no} = 0.9$
#         - $p_{yes} = \frac{TP+TN}{Total}* \frac{TP+FN}{Total} = \frac{9+1}{10}* \frac{9+0}{10}=0.9$
#         - $p_{no} = \frac{FN+TN}{Total}* \frac{FP+TN}{Total} = 0$
#     - $k = \frac{p_0-p_e}{1 - p_e}=\frac{0.9-0.9}{1 - 0.9}=0$ </br>
#
# See that the 2 only relevant indicators in this case are:
# - Specificity: tells me that my model is bad at predicting True Negative
# - Cohen' Kappa: tells me that my predictions are random

# %% [markdown]
# ### Precision Recall Trade-off and ROC Curve

# %% [markdown]
# <table style="width:100%" style="text-align:left">
#     <tr style="width:50%">
#         <td style="text-align:left"><b>Source</b>:<a href="https://www.youtube.com/watch?v=4jRBRDbJemM&ab_channel=StatQuestwithJoshStarmer">youtube video</a>  </br> I won't review this part in detail as I believe that a video is the best format to explain ROC-AUC, but, in a nutshell: x-axis = false positive rate, y-axis = true positive rate, so your goal is to find the point on the curve that is the most on the top left to get the optimum prediction if your goal is purely accuracy.
#         </td>
#         <td style="text-align:left"> Similarly, you can find the precision (of the predicted positive, what percentage was actually positive) and  recall (of all the positives, what percentage was actually predicted as positive) trade-off curve
#         </td>
#     </tr>
#     <tr style="width:50%">
#         <td>
#            <img src="https://emj.bmj.com/content/emermed/34/6/357/F1.large.jpg" width=400 >
#         </td>
#         <td>
#             <img src = "https://miro.medium.com/max/1248/1*TqzfzabXrej1FTdZuNNYIQ.png">
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Double density plot

# %% [markdown]
# As ROC and AUC might be hard to interpret, you can use another solution: double density plot
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regression Metrics

# %% [markdown]
# - Non-exhaustive list
# - Focus on distance of residuals from prediction
#
# <img src="https://miro.medium.com/max/1356/1*L6y8w5-rTdUc0zhqVd_Qag.png" width=300>

# %% [markdown]
# <table style = align-text:left>
# <thead>
#   <tr>
#     <th>Measure</th>
#     <th>Formula</th>
#     <th>Range</th>
#     <th>Advantages</th>
#     <th>Disadvantages</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td style = width:10%>MAE</td>
#     <td style = width:20%>$\sum_{i=1}^{D}|x_i-y_i|$</td>
#     <td>down to 0</td>
#     <td>Same unit as response variable<br>Robust to outliers</td>
#     <td>Hard to interpret and roll-up on how to improve the model (you can report it but do not use it as a final goal)</td>
#   </tr>
#   <tr>
#     <td>MSE</td>
#     <td>$\sum_{i=1}^{D}(x_i-y_i)^2$</td>
#     <td>down to 0</td>
#     <td>Can be easily used as a loss function</td>
#     <td>Different unit<br>Sensitive to outliers (which can be an advantage as well)</td>
#   </tr>
#   <tr>
#     <td>RMSE</td>
#     <td>$sqrt{\sum_{i=1}^{D}(x_i-y_i)^2}$</td>
#     <td>down to 0</td>
#     <td>Same Unit<br>Easy interpretation<br>most common goodness of fit</td>
#     <td>Not robust to outliers</td>
#   </tr>
#   <tr>
#     <td>RMSLE</td>
#     <td>>$sqrt{\sum_log({i=1}^{D}(x_i-y_i))^2}$</td>
#     <td>down to 0</td>
#     <td>Commonly used in kaggle competition </td>
#     <td>but I do not get it</td>
#   </tr>
#   <tr>
#     <td>R squared</td>
#     <td></td>
#     <td>0 to 1</td>
#     <td>Tells us how well perform our model</td>
#     <td>Hard to explain in business<br>Become irrelevant when adding new features</td>
#   </tr>
#   <tr>
#     <td>Adjusted R Squares</td>
#     <td></td>
#     <td>0 to 1</td>
#     <td>Better when adding new features</td>
#     <td></td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Clustering

# %% [markdown]
# We won't review it here </br>
# **To go further:** https://towardsdatascience.com/performance-metrics-in-machine-learning-part-3-clustering-d69550662dc6
